# %%
# Test FastF1
import fastf1
fastf1.Cache.enable_cache('f1_cache')

# Check if 2025 data is available
try:
    schedule_2025 = fastf1.get_event_schedule(2025)
    print(f"✅ 2025 Season: {len(schedule_2025)} rounds available")
    
    # Check which rounds exist
    print("\n2025 Race Calendar:")
    print(schedule_2025[['RoundNumber', 'EventName', 'EventDate']])
    
    # Test fetching Round 20 (Mexico) data
    print("\n🧪 Testing Mexico GP R20 data fetch...")
    session = fastf1.get_session(2025, 20, 'R')
    session.load()
    print(f"✅ Mexico GP data available: {len(session.results)} drivers")
    
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Test FastF1
# ----> 2 import fastf1
#       3 fastf1.Cache.enable_cache('f1_cache')
#       5 # Check if 2025 data is available
#
# ModuleNotFoundError: No module named 'fastf1'
